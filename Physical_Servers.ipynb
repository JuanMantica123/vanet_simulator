# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import vanet_tools as vp

# %%
micro_df = pd.read_csv('manhattan_config.csv',index_col=0).values

# %%
p_v_ratio, num_virtual = 1/5,len(micro_df)
num_physical = int(p_v_ratio*num_virtual)

# %%
kmeans = KMeans(n_clusters=num_physical).fit(micro_df)
y_kmeans = kmeans.predict(micro_df)

# %%
plt.scatter(micro_df[:, 0], micro_df[:, 1], c=y_kmeans, s=50, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
ks = [k for k in range(1,len(micro_df)+1)]
sum_of_squared_distances = []
for k in ks:
    kmeans = KMeans(n_clusters=k).fit(micro_df)
    sum_of_squared_distances.append(kmeans.inertia_)

# %%
plt.plot(ks,sum_of_squared_distances)
plt.show()

# %%
new_york_df = pd.read_csv('new_york_config.csv',index_col=0).values

# %%
num_physical_ny = int(p_v_ratio*len(new_york_df))

# %%
kmeans_ny = KMeans(n_clusters=num_physical_ny).fit(new_york_df)
y_kmeans_ny = kmeans.predict(micro_df)

# %%
plt.scatter(new_york_df[:, 0], new_york_df[:, 1], c=y_kmeans_ny, s=50, cmap='viridis')
centers_ny = kmeans_ny.cluster_centers_
plt.scatter(centers_ny[:, 0], centers_ny[:, 1], c='black', s=200, alpha=0.5);
